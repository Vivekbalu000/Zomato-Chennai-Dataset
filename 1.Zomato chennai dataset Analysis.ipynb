# %% [markdown]
# # 1. Importing the libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.io as pio
pio.renderers.default = "svg"

# %% [markdown]
# # 2. Importing the dataset

# %%
raw_df = pd.read_csv('Zomato_Chennai_Dataset.csv',delimiter='|')

# %%
raw_df
# Out:
#                               NAME PRICE  \
# 0            Dhaba Estd 1986 Delhi  1500
# 1                   Copper Kitchen   800
# 2                        Palmshore  1000
# 3                   Guntur Gongura   400
# 4                        Hoppipola  1400
# ...                            ...   ...
# 5163                Hotel Kurinchi   400
# 5164            Hung' Bites & Cafe   450
# 5165                Ladle & Spices   600
# 5166  Malabar Biriyani & Fast Food   150
# 5167                                NaN
#
#                                         CUSINE_CATEGORY     CITY  \
# 0                       North Indian,Desserts,Beverages  Chennai
# 1          Seafood,North Indian,Chinese,Mughlai,Biryani  Chennai
# 2     Seafood,Biryani,Kebab,North Indian,Chinese,Ara...  Chennai
# 3                          North Indian,Chinese,Biryani  Chennai
# 4                    Continental,Mediterranean,American  Chennai
# ...                                                 ...      ...
# 5163                             Chettinad,South Indian  Chennai
# 5164        Cafe,Italian,Sandwich,Beverages,Continental  Chennai
# 5165                                       North Indian  Chennai
# 5166                               Biryani,South Indian  Chennai
# 5167                                                NaN      NaN
#
#                                REGION  \
# 0      Ispahani Centre-- Nungambakkam
# 1                               Porur
# 2                         Ashok Nagar
# 3                      Sholinganallur
# 4     The Spring Hotel-- Nungambakkam
# ...                               ...
# 5163                        Park Town
# 5164                         GST Road
# 5165        The King's Hotel-- Egmore
# 5166                      Maduravoyal
# 5167                              NaN
#
#                                                     URL PAGE NO  \
# 0     https://www.zomato.com/chennai/dhaba-estd-1986...       1
# 1     https://www.zomato.com/chennai/copper-kitchen-...       1
# 2     https://www.zomato.com/chennai/palmshore-ashok...       1
# 3     https://www.zomato.com/chennai/guntur-gongura-...       1
# 4     https://www.zomato.com/chennai/hoppipola-nunga...       1
# ...                                                 ...     ...
# 5163  https://www.zomato.com/chennai/hotel-kurinchi-...      99
# 5164  https://www.zomato.com/chennai/hung-bites-cafe...      99
# 5165  https://www.zomato.com/chennai/ladle-spices-eg...      99
# 5166  https://www.zomato.com/chennai/malabar-biriyan...      99
# 5167                                                NaN     NaN
#
#         CUSINE TYPE                                             TIMING  \
# 0     Casual Dining  12noon to 4pm,6pm to 1130pm(Mon-Thu),12noon to...
# 1     Casual Dining                               11am to 2am(Mon-Sun)
# 2     Casual Dining                             1130am to 1am(Mon-Sun)
# 3     Casual Dining                                6am to 2am(Mon-Sun)
# 4               Bar       3pm to 1130pm(Mon),12noon to 1130pm(Tue-Sun)
# ...             ...                                                ...
# 5163    Quick Bites                               6am to 10pm(Mon-Sun)
# 5164           Café                               2pm to 11pm(Mon-Sun)
# 5165  Casual Dining   7am to 1030am,12noon to 4pm,7pm to 11pm(Mon-Sun)
# 5166    Quick Bites                               9am to 11pm(Mon-Sun)
# 5167            NaN                                                NaN
#
#      RATING_TYPE RATING VOTES
# 0      Excellent    4.6  1284
# 1      Excellent    4.6  3927
# 2      Excellent    4.5  3203
# 3           Good    3.7  2086
# 4      Very Good    4.2   959
# ...          ...    ...   ...
# 5163        Good    3.6    41
# 5164        Good    3.7    50
# 5165     Average    3.3    49
# 5166        Good    3.6    46
# 5167         NaN    NaN   NaN
#
# [5168 rows x 12 columns]

# %% [markdown]
# # 3. Getting Basic Information about the Dataset

# %%
raw_df.shape
# Out:
# (5168, 12)

# %%
raw_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5168 entries, 0 to 5167
# Data columns (total 12 columns):
# NAME               5168 non-null object
# PRICE              5167 non-null object
# CUSINE_CATEGORY    5167 non-null object
# CITY               5167 non-null object
# REGION             5167 non-null object
# URL                5167 non-null object
# PAGE NO            5167 non-null object
# CUSINE TYPE        5167 non-null object
# TIMING             5152 non-null object
# RATING_TYPE        5167 non-null object
# RATING             5167 non-null object
# VOTES              5167 non-null object
# dtypes: object(12)
# memory usage: 484.6+ KB

# %%
raw_df.describe()
# Out:
#         NAME PRICE CUSINE_CATEGORY     CITY  REGION   URL  PAGE NO  \
# count   5168  5167            5167     5167    5167  5167     5167
# unique  4649    45            1406        2     188  4845      324
# top     NAME   300    South Indian  Chennai  REGION   URL  PAGE NO
# freq     322   984             409     4845     322   322      322
#
#         CUSINE TYPE                 TIMING RATING_TYPE RATING VOTES
# count          5167                   5152        5167   5167  5167
# unique           19                   1030          15     33   634
# top     Quick Bites  11am to 11pm(Mon-Sun)     Average      -     -
# freq           2316                    929        1751    909   909

# %% [markdown]
# # 4. Cleaning the Dataset
# # a. Removing the redundunt rows of data

# %%
# Checking redundunt rows of data


wrong_data=raw_df['PAGE NO']=='PAGE NO'
raw_df[wrong_data]
# Out:
#       NAME  PRICE  CUSINE_CATEGORY  CITY  REGION  URL  PAGE NO  CUSINE TYPE  \
# 15    NAME  PRICE  CUSINE_CATEGORY  CITY  REGION  URL  PAGE NO  CUSINE TYPE
# 31    NAME  PRICE  CUSINE_CATEGORY  CITY  REGION  URL  PAGE NO  CUSINE TYPE
# 47    NAME  PRICE  CUSINE_CATEGORY  CITY  REGION  URL  PAGE NO  CUSINE TYPE
# 63    NAME  PRICE  CUSINE_CATEGORY  CITY  REGION  URL  PAGE NO  CUSINE TYPE
# 79    NAME  PRICE  CUSINE_CATEGORY  CITY  REGION  URL  PAGE NO  CUSINE TYPE
# ...    ...    ...              ...   ...     ...  ...      ...          ...
# 5087  NAME  PRICE  CUSINE_CATEGORY  CITY  REGION  URL  PAGE NO  CUSINE TYPE
# 5103  NAME  PRICE  CUSINE_CATEGORY  CITY  REGION  URL  PAGE NO  CUSINE TYPE
# 5119  NAME  PRICE  CUSINE_CATEGORY  CITY  REGION  URL  PAGE NO  CUSINE TYPE
# 5135  NAME  PRICE  CUSINE_CATEGORY  CITY  REGION  URL  PAGE NO  CUSINE TYPE
# 5151  NAME  PRICE  CUSINE_CATEGORY  CITY  REGION  URL  PAGE NO  CUSINE TYPE
#
#       TIMING  RATING_TYPE  RATING  VOTES
# 15    TIMING  RATING_TYPE  RATING  VOTES
# 31    TIMING  RATING_TYPE  RATING  VOTES
# 47    TIMING  RATING_TYPE  RATING  VOTES
# 63    TIMING  RATING_TYPE  RATING  VOTES
# 79    TIMING  RATING_TYPE  RATING  VOTES
# ...      ...          ...     ...    ...
# 5087  TIMING  RATING_TYPE  RATING  VOTES
# 5103  TIMING  RATING_TYPE  RATING  VOTES
# 5119  TIMING  RATING_TYPE  RATING  VOTES
# 5135  TIMING  RATING_TYPE  RATING  VOTES
# 5151  TIMING  RATING_TYPE  RATING  VOTES
#
# [322 rows x 12 columns]

# %%
## Performing Negation of the wrong dataset and then storing the correct data back in the raw_df DataFrame
## This permamnently remove the wrong data from the original dataframe

raw_df = raw_df[~wrong_data]

# %%
# Dropping columns which are not required for further analysis

raw_df.drop(['URL', 'PAGE NO', 'CITY'], axis = 1, inplace=True)
# Out:
# C:\Users\Hi\anaconda3\envs\ven\lib\site-packages\pandas\core\frame.py:4117: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
raw_df.head()
# Out:
#                     NAME PRICE  \
# 0  Dhaba Estd 1986 Delhi  1500
# 1         Copper Kitchen   800
# 2              Palmshore  1000
# 3         Guntur Gongura   400
# 4              Hoppipola  1400
#
#                                      CUSINE_CATEGORY  \
# 0                    North Indian,Desserts,Beverages
# 1       Seafood,North Indian,Chinese,Mughlai,Biryani
# 2  Seafood,Biryani,Kebab,North Indian,Chinese,Ara...
# 3                       North Indian,Chinese,Biryani
# 4                 Continental,Mediterranean,American
#
#                             REGION    CUSINE TYPE  \
# 0   Ispahani Centre-- Nungambakkam  Casual Dining
# 1                            Porur  Casual Dining
# 2                      Ashok Nagar  Casual Dining
# 3                   Sholinganallur  Casual Dining
# 4  The Spring Hotel-- Nungambakkam            Bar
#
#                                               TIMING RATING_TYPE RATING VOTES
# 0  12noon to 4pm,6pm to 1130pm(Mon-Thu),12noon to...   Excellent    4.6  1284
# 1                               11am to 2am(Mon-Sun)   Excellent    4.6  3927
# 2                             1130am to 1am(Mon-Sun)   Excellent    4.5  3203
# 3                                6am to 2am(Mon-Sun)        Good    3.7  2086
# 4       3pm to 1130pm(Mon),12noon to 1130pm(Tue-Sun)   Very Good    4.2   959

# %% [markdown]
# # b. Removing the Null Records

# %%
# Checking for a null records

raw_df.isnull().sum()
# Out:
# NAME                0
# PRICE               1
# CUSINE_CATEGORY     1
# REGION              1
# CUSINE TYPE         1
# TIMING             16
# RATING_TYPE         1
# RATING              1
# VOTES               1
# dtype: int64

# %%
# Checking for a null row

raw_df[raw_df['PRICE'].isnull()]
# Out:
#      NAME PRICE CUSINE_CATEGORY REGION CUSINE TYPE TIMING RATING_TYPE RATING  \
# 5167       NaN             NaN    NaN         NaN    NaN         NaN    NaN
#
#      VOTES
# 5167   NaN

# %%
# Droping the above row from the dataset

raw_df=raw_df.drop(labels=5167,axis=0)

# %%
# Replacing the other null records with NA

raw_df.fillna('NA',inplace=True)

# %%
# Confirming all the null records are correct

raw_df.isnull().sum()
# Out:
# NAME               0
# PRICE              0
# CUSINE_CATEGORY    0
# REGION             0
# CUSINE TYPE        0
# TIMING             0
# RATING_TYPE        0
# RATING             0
# VOTES              0
# dtype: int64

# %% [markdown]
# # c. Converting the DataTypes of numerical columns to numeric dataype

# %%
# Checking for text values in the column before converting it to numeric datatype

raw_df['RATING'].value_counts()
# Out:
# -          909
# NEW        381
# 3.3        364
# 3.4        339
# 3.2        328
# 3.5        317
# 3.6        306
# 3.7        273
# 3.1        260
# 3.8        215
# 3.9        188
# 3.0        183
# 4.0        144
# 2.9        135
# 4.1        108
# 4.2         77
# 2.8         74
# 4.3         61
# 2.7         37
# 4.4         37
# 4.5         21
# 2.6         21
# 4.6         15
# Opening     14
# 2.5         13
# 4.7         10
# 2.4          6
# 4.8          3
# 2.2          2
# 2.1          2
# 2.3          1
# 4.9          1
# Name: RATING, dtype: int64

# %%
# Replacing the text values with '0'


raw_df['RATING'].replace(to_replace=['-','NEW','Opening'],value='0',inplace=True)

# %%
# Checking for text values in the column before converting it to numeric datatype

raw_df['VOTES'].value_counts()
# Out:
# -       909
# NEW     381
# 4       126
# 6       100
# 5        91
#        ...
# 1404      1
# 790       1
# 271       1
# 742       1
# 677       1
# Name: VOTES, Length: 633, dtype: int64

# %%
# Replacing the text values with '0'

raw_df['VOTES'].replace(to_replace=['-','NEW','Opening'],value='0',inplace=True)

# %%
raw_df['RATING'].value_counts()
# Out:
# 0      1304
# 3.3     364
# 3.4     339
# 3.2     328
# 3.5     317
# 3.6     306
# 3.7     273
# 3.1     260
# 3.8     215
# 3.9     188
# 3.0     183
# 4.0     144
# 2.9     135
# 4.1     108
# 4.2      77
# 2.8      74
# 4.3      61
# 2.7      37
# 4.4      37
# 4.5      21
# 2.6      21
# 4.6      15
# 2.5      13
# 4.7      10
# 2.4       6
# 4.8       3
# 2.2       2
# 2.1       2
# 2.3       1
# 4.9       1
# Name: RATING, dtype: int64

# %%
raw_df['VOTES'].value_counts()
# Out:
# 0      1304
# 4       126
# 6       100
# 5        91
# 7        88
#        ...
# 790       1
# 271       1
# 742       1
# 621       1
# 864       1
# Name: VOTES, Length: 631, dtype: int64

# %%
raw_df.dtypes
# Out:
# NAME               object
# PRICE              object
# CUSINE_CATEGORY    object
# REGION             object
# CUSINE TYPE        object
# TIMING             object
# RATING_TYPE        object
# RATING             object
# VOTES              object
# dtype: object

# %%
# Changing Data Type of the numerical columns

raw_df['PRICE'] = raw_df['PRICE'].astype('int64')
raw_df['RATING'] = raw_df['RATING'].astype('float64')
raw_df['VOTES']=raw_df['VOTES'].astype('int64')

# %%
raw_df.dtypes
# Out:
# NAME                object
# PRICE                int64
# CUSINE_CATEGORY     object
# REGION              object
# CUSINE TYPE         object
# TIMING              object
# RATING_TYPE         object
# RATING             float64
# VOTES                int64
# dtype: object

# %%
raw_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4845 entries, 0 to 5166
# Data columns (total 9 columns):
# NAME               4845 non-null object
# PRICE              4845 non-null int64
# CUSINE_CATEGORY    4845 non-null object
# REGION             4845 non-null object
# CUSINE TYPE        4845 non-null object
# TIMING             4845 non-null object
# RATING_TYPE        4845 non-null object
# RATING             4845 non-null float64
# VOTES              4845 non-null int64
# dtypes: float64(1), int64(2), object(6)
# memory usage: 378.5+ KB

# %% [markdown]
# # d. Working with 'Timing' column

# %%
raw_df['TIMING'].value_counts()
# Out:
# 11am to 11pm(Mon-Sun)                           929
# 12noon to 11pm(Mon-Sun)                         155
# 10am to 10pm(Mon-Sun)                           145
# 7am to 11pm(Mon-Sun)                            134
# 1130am to 1130pm(Mon-Sun)                        94
#                                                ...
# 5am to 10pm(Mon-Sun)                              1
# 1130am to 1130pm(Mon,Tue,Wed,Thu,Sat,Sun)...      1
# 7am to 12noon(Mon-Sun)                            1
# 12noon to 3pm,4pm to 10pm(Mon-Sun)                1
# 12noon to 9pm(Mon-Sat),12noon to 5am(Sun)         1
# Name: TIMING, Length: 1030, dtype: int64

# %%
# Splitting the column and storing it in temp_df dataframe 

temp_df = raw_df['TIMING'].str.split("(", n = 1, expand = True)
temp_df
# Out:
#                                             0                               1
# 0                 12noon to 4pm,6pm to 1130pm          Mon-Thu),12noon to ...
# 1                                 11am to 2am                        Mon-Sun)
# 2                               1130am to 1am                        Mon-Sun)
# 3                                  6am to 2am                        Mon-Sun)
# 4                               3pm to 1130pm  Mon),12noon to 1130pm(Tue-Sun)
# ...                                       ...                             ...
# 5162                   8am to 4pm,7pm to 11pm                        Mon-Sun)
# 5163                              6am to 10pm                        Mon-Sun)
# 5164                              2pm to 11pm                        Mon-Sun)
# 5165  7am to 1030am,12noon to 4pm,7pm to 11pm                        Mon-Sun)
# 5166                              9am to 11pm                        Mon-Sun)
#
# [4845 rows x 2 columns]

# %%
# Assigning the columns back to the raw_df dataframe

raw_df['TIMING'] = temp_df[0]
raw_df['DAYS_OPEN'] = temp_df[1]
raw_df.head()
# Out:
#                     NAME  PRICE  \
# 0  Dhaba Estd 1986 Delhi   1500
# 1         Copper Kitchen    800
# 2              Palmshore   1000
# 3         Guntur Gongura    400
# 4              Hoppipola   1400
#
#                                      CUSINE_CATEGORY  \
# 0                    North Indian,Desserts,Beverages
# 1       Seafood,North Indian,Chinese,Mughlai,Biryani
# 2  Seafood,Biryani,Kebab,North Indian,Chinese,Ara...
# 3                       North Indian,Chinese,Biryani
# 4                 Continental,Mediterranean,American
#
#                             REGION    CUSINE TYPE  \
# 0   Ispahani Centre-- Nungambakkam  Casual Dining
# 1                            Porur  Casual Dining
# 2                      Ashok Nagar  Casual Dining
# 3                   Sholinganallur  Casual Dining
# 4  The Spring Hotel-- Nungambakkam            Bar
#
#                         TIMING RATING_TYPE  RATING  VOTES  \
# 0  12noon to 4pm,6pm to 1130pm   Excellent     4.6   1284
# 1                  11am to 2am   Excellent     4.6   3927
# 2                1130am to 1am   Excellent     4.5   3203
# 3                   6am to 2am        Good     3.7   2086
# 4                3pm to 1130pm   Very Good     4.2    959
#
#                         DAYS_OPEN
# 0          Mon-Thu),12noon to ...
# 1                        Mon-Sun)
# 2                        Mon-Sun)
# 3                        Mon-Sun)
# 4  Mon),12noon to 1130pm(Tue-Sun)

# %%
# Removing the bracket character from Days column

raw_df['DAYS_OPEN'] = raw_df['DAYS_OPEN'].str.replace(')','',regex=True)
raw_df.head()
# Out:
#                     NAME  PRICE  \
# 0  Dhaba Estd 1986 Delhi   1500
# 1         Copper Kitchen    800
# 2              Palmshore   1000
# 3         Guntur Gongura    400
# 4              Hoppipola   1400
#
#                                      CUSINE_CATEGORY  \
# 0                    North Indian,Desserts,Beverages
# 1       Seafood,North Indian,Chinese,Mughlai,Biryani
# 2  Seafood,Biryani,Kebab,North Indian,Chinese,Ara...
# 3                       North Indian,Chinese,Biryani
# 4                 Continental,Mediterranean,American
#
#                             REGION    CUSINE TYPE  \
# 0   Ispahani Centre-- Nungambakkam  Casual Dining
# 1                            Porur  Casual Dining
# 2                      Ashok Nagar  Casual Dining
# 3                   Sholinganallur  Casual Dining
# 4  The Spring Hotel-- Nungambakkam            Bar
#
#                         TIMING RATING_TYPE  RATING  VOTES  \
# 0  12noon to 4pm,6pm to 1130pm   Excellent     4.6   1284
# 1                  11am to 2am   Excellent     4.6   3927
# 2                1130am to 1am   Excellent     4.5   3203
# 3                   6am to 2am        Good     3.7   2086
# 4                3pm to 1130pm   Very Good     4.2    959
#
#                       DAYS_OPEN
# 0         Mon-Thu,12noon to ...
# 1                       Mon-Sun
# 2                       Mon-Sun
# 3                       Mon-Sun
# 4  Mon,12noon to 1130pm(Tue-Sun

# %%
# Checking for Null records in DAYS_OPEN column

raw_df.isnull().sum()
# Out:
# NAME                0
# PRICE               0
# CUSINE_CATEGORY     0
# REGION              0
# CUSINE TYPE         0
# TIMING              0
# RATING_TYPE         0
# RATING              0
# VOTES               0
# DAYS_OPEN          65
# dtype: int64

# %%
# Replacing the Null values with 'NA'

raw_df.fillna('NA', inplace=True)

# %%
raw_df.isnull().sum()
# Out:
# NAME               0
# PRICE              0
# CUSINE_CATEGORY    0
# REGION             0
# CUSINE TYPE        0
# TIMING             0
# RATING_TYPE        0
# RATING             0
# VOTES              0
# DAYS_OPEN          0
# dtype: int64

# %%
# Checking info of all the columns

raw_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4845 entries, 0 to 5166
# Data columns (total 10 columns):
# NAME               4845 non-null object
# PRICE              4845 non-null int64
# CUSINE_CATEGORY    4845 non-null object
# REGION             4845 non-null object
# CUSINE TYPE        4845 non-null object
# TIMING             4845 non-null object
# RATING_TYPE        4845 non-null object
# RATING             4845 non-null float64
# VOTES              4845 non-null int64
# DAYS_OPEN          4845 non-null object
# dtypes: float64(1), int64(2), object(7)
# memory usage: 416.4+ KB

# %% [markdown]
# # e. Removing the restaurant records whose Rating or Votes is 0

# %%
# Finding those restaurant whose has 0 Rating or Votes

useless_data = (raw_df['RATING'] == 0.0) | (raw_df['VOTES'] == 0)
raw_df[useless_data]
# Out:
#                          NAME  PRICE  \
# 71          Out of the Bottle    300
# 145    Salakaydoom Restaurant    300
# 222      Spicy Indian Burgers    500
# 318              Zucca Shakes    350
# 384                 Yum_Torte    400
# ...                       ...    ...
# 4899              Cream Point    500
# 4914    Yaa Mohaideen Biryani    400
# 5111  NICO Coffee House & Bar   1000
# 5156             Lassi Bistro    150
# 5158   Madurai KB Konaar Mess    500
#
#                                  CUSINE_CATEGORY  \
# 71                  Beverages,Desserts,Fast Food
# 145                 South Indian,Seafood,Biryani
# 222              Cafe,Fast Food,Burger,Beverages
# 318                                    Beverages
# 384                                       Bakery
# ...                                          ...
# 4899                Mexican,Italian,North Indian
# 4914                                     Biryani
# 5111  Finger Food,Chinese,South Indian,Fast Food
# 5156                                   Beverages
# 5158                                South Indian
#
#                              REGION    CUSINE TYPE  \
# 71                      Gopalapuram  Beverage Shop
# 145   OMR Food Street-- Perumbakkam  Casual Dining
# 222                       Perungudi           Café
# 318                    Pallikaranai  Beverage Shop
# 384                       Mogappair           none
# ...                             ...            ...
# 4899          East Coast Road (ECR)  Casual Dining
# 4914                     Medavakkam  Casual Dining
# 5111          Novotel Chennai-- OMR            Bar
# 5156                    Choolaimedu  Beverage Shop
# 5158                       Alwarpet    Quick Bites
#
#                              TIMING RATING_TYPE  RATING  VOTES DAYS_OPEN
# 71                   1130am to 11pm        None     0.0      0   Mon-Sun
# 145                    11am to 11pm        None     0.0      0   Mon-Sun
# 222                    11am to 11pm        None     0.0      0   Mon-Sun
# 318                    11am to 11pm        None     0.0      0   Mon-Sun
# 384                     10am to 8pm   Not rated     0.0      0   Mon-Sun
# ...                             ...         ...     ...    ...       ...
# 4899  12noon to 330pm,7pm to 1030pm        None     0.0      0   Mon-Sun
# 4914                   11am to 10pm        None     0.0      0   Mon-Sun
# 5111                   11am to 11pm        None     0.0      0   Mon-Sun
# 5156                   11am to 11pm        None     0.0      0   Mon-Sun
# 5158                   11am to 11pm        None     0.0      0   Mon-Sun
#
# [1304 rows x 10 columns]

# %%
## Performing Negation of the useless dataset and then storing the correct data back in the raw_df DataFrame
## This permamnently remove the wrong data from the original dataframe

raw_df = raw_df[~useless_data]

# %%
raw_df
# Out:
#                               NAME  PRICE  \
# 0            Dhaba Estd 1986 Delhi   1500
# 1                   Copper Kitchen    800
# 2                        Palmshore   1000
# 3                   Guntur Gongura    400
# 4                        Hoppipola   1400
# ...                            ...    ...
# 5162            Bengali Restaurant    400
# 5163                Hotel Kurinchi    400
# 5164            Hung' Bites & Cafe    450
# 5165                Ladle & Spices    600
# 5166  Malabar Biriyani & Fast Food    150
#
#                                         CUSINE_CATEGORY  \
# 0                       North Indian,Desserts,Beverages
# 1          Seafood,North Indian,Chinese,Mughlai,Biryani
# 2     Seafood,Biryani,Kebab,North Indian,Chinese,Ara...
# 3                          North Indian,Chinese,Biryani
# 4                    Continental,Mediterranean,American
# ...                                                 ...
# 5162                                            Bengali
# 5163                             Chettinad,South Indian
# 5164        Cafe,Italian,Sandwich,Beverages,Continental
# 5165                                       North Indian
# 5166                               Biryani,South Indian
#
#                                REGION    CUSINE TYPE  \
# 0      Ispahani Centre-- Nungambakkam  Casual Dining
# 1                               Porur  Casual Dining
# 2                         Ashok Nagar  Casual Dining
# 3                      Sholinganallur  Casual Dining
# 4     The Spring Hotel-- Nungambakkam            Bar
# ...                               ...            ...
# 5162                           Egmore    Quick Bites
# 5163                        Park Town    Quick Bites
# 5164                         GST Road           Café
# 5165        The King's Hotel-- Egmore  Casual Dining
# 5166                      Maduravoyal    Quick Bites
#
#                                        TIMING RATING_TYPE  RATING  VOTES  \
# 0                 12noon to 4pm,6pm to 1130pm   Excellent     4.6   1284
# 1                                 11am to 2am   Excellent     4.6   3927
# 2                               1130am to 1am   Excellent     4.5   3203
# 3                                  6am to 2am        Good     3.7   2086
# 4                               3pm to 1130pm   Very Good     4.2    959
# ...                                       ...         ...     ...    ...
# 5162                   8am to 4pm,7pm to 11pm     Average     3.3     36
# 5163                              6am to 10pm        Good     3.6     41
# 5164                              2pm to 11pm        Good     3.7     50
# 5165  7am to 1030am,12noon to 4pm,7pm to 11pm     Average     3.3     49
# 5166                              9am to 11pm        Good     3.6     46
#
#                          DAYS_OPEN
# 0            Mon-Thu,12noon to ...
# 1                          Mon-Sun
# 2                          Mon-Sun
# 3                          Mon-Sun
# 4     Mon,12noon to 1130pm(Tue-Sun
# ...                            ...
# 5162                       Mon-Sun
# 5163                       Mon-Sun
# 5164                       Mon-Sun
# 5165                       Mon-Sun
# 5166                       Mon-Sun
#
# [3541 rows x 10 columns]

# %% [markdown]
# # f. Working on 'RATING_TYPE' Column

# %%
# Checking the unique values in the column

raw_df['RATING_TYPE'].value_counts()
# Out:
# Average         1751
# Good            1297
# Very Good        422
# Excellent         49
# Poor              11
# Çok iyi            4
# Průměr             2
# Wybitnie           1
# Baik               1
# Sangat Baik        1
# Średnio            1
# Skvělá volba       1
# Name: RATING_TYPE, dtype: int64

# %%
# Translating the texts into proper English text

raw_df['RATING_TYPE'].replace(to_replace='Excelente' , value='Excellent', inplace=True)
raw_df['RATING_TYPE'].replace(to_replace=['Çok iyi','Średnio'],value='Average',inplace=True)
raw_df['RATING_TYPE'].replace(to_replace='Průměr',value='Poor',inplace=True)
raw_df['RATING_TYPE'].replace(to_replace=['Baik','Sangat Baik'], value='Very Poor',inplace=True)
raw_df['RATING_TYPE'].replace(to_replace=['Wybitnie','Skvělá volba'],value='Good',inplace=True)

# %%
# Checking all the values correctly mapped

raw_df['RATING_TYPE'].value_counts()
# Out:
# Average      1756
# Good         1299
# Very Good     422
# Excellent      49
# Poor           13
# Very Poor       2
# Name: RATING_TYPE, dtype: int64

# %% [markdown]
# # g. Working on 'REGION' Column

# %%
raw_df['REGION'].value_counts()
# Out:
# Anna Nagar East                         133
# T. Nagar                                107
# Nungambakkam                            105
# Velachery                               105
# Porur                                    92
#                                        ...
# Eat And Pack-- Ambattur                   1
# Green Park Hotel-- Vadapalani             1
# Kora Food Street-- Anna Nagar West        1
# Grand by GRT Hotels                       1
# Spencer Plaza Mall-- Thousand Lights      1
# Name: REGION, Length: 180, dtype: int64

# %%
# Removing the irrelevant text from the Region column

raw_df['REGION'] = raw_df['REGION'].str.replace('[a-zA-Z].+-- ','',regex=True)

# %%
# Removing the West & East from the Region column

raw_df['REGION'] = raw_df['REGION'].str.replace(' West| west| East| east','',regex=True)

# %%
raw_df['REGION'].value_counts()
# Out:
# Anna Nagar                229
# Velachery                 124
# Nungambakkam              118
# T. Nagar                  113
# Porur                      92
#                          ...
# Grand by GRT Hotels         1
# Citadines                   1
# Vettuvankeni                1
# Novotel Chennai Sipcot      1
# Old Mahabalipuram Road      1
# Name: REGION, Length: 115, dtype: int64

# %%
# Replacing Small regions with Known region name

raw_df['REGION'] = raw_df['REGION'].str.replace('Vettuvankeni|Eldoris|Citadines|Old Mahabalipuram Road' ,'Velachery',regex=True)

raw_df['REGION'] = raw_df['REGION'].str.replace('Grand by GRT Hotels|Novotel Chennai Sipcot|The Slate|Somerset Greenways', 
                                                'T. Nagar',regex=True)

raw_df['REGION'] = raw_df['REGION'].str.replace('Novotel Chennai Sipcot|Redhills','Porur',regex=True)

raw_df['REGION'] = raw_df['REGION'].str.replace('Muttukadu|Kovalam|Holiday Inn Chennai OMR IT Expressway|MRC Nagar|Foodies Kitchen',
                                                'ECR',regex=True)

raw_df['REGION'] = raw_df['REGION'].str.replace('T.Nagar| St. Thomas Mount|Okkiyampet|Royapettah|Tiruvottiyur|T.Nagar ',
                                                'T.Nagar',regex=True)
raw_df['REGION'] = raw_df['REGION'].str.replace('East Coast Road (ECR)','ECR',regex=True)

raw_df['REGION'] = raw_df['REGION'].str.replace('Anna Salai','Central Chennai',regex=True)

raw_df['REGION'] = raw_df['REGION'].str.replace('St. Thomas Mount ','Guindy',regex=True)

# %%
raw_df['REGION'].value_counts()
# Out:
# Anna Nagar               229
# Velachery                128
# T. Nagar                 119
# Nungambakkam             118
# Porur                     94
#                         ...
# East Coast Road (ECR)      6
# Abhiramapuram              5
# St. Thomas Mount           5
# Central Chennai            5
#  T.Nagar                   4
# Name: REGION, Length: 98, dtype: int64

# %% [markdown]
# # h. Removing Duplicate records

# %%
# Finding all the duplicate rows

raw_df[raw_df.duplicated()]
# Out:
#                 NAME  PRICE                       CUSINE_CATEGORY  \
# 4848  Biryani Darbar    500  Bengali,Biryani,North Indian,Chinese
#
#              REGION  CUSINE TYPE        TIMING RATING_TYPE  RATING  VOTES  \
# 4848  Virugambakkam  Quick Bites  11am to 11pm     Average     2.6     94
#
#      DAYS_OPEN
# 4848   Mon-Sun

# %%
# Dropping all the duplicate rows

raw_df = raw_df.drop_duplicates()

# %% [markdown]
# # 4. Copying the cleaned data into a new DataFrame

# %%
zomato_df = raw_df.copy()

# %%
zomato_df.head()
# Out:
#                     NAME  PRICE  \
# 0  Dhaba Estd 1986 Delhi   1500
# 1         Copper Kitchen    800
# 2              Palmshore   1000
# 3         Guntur Gongura    400
# 4              Hoppipola   1400
#
#                                      CUSINE_CATEGORY          REGION  \
# 0                    North Indian,Desserts,Beverages    Nungambakkam
# 1       Seafood,North Indian,Chinese,Mughlai,Biryani           Porur
# 2  Seafood,Biryani,Kebab,North Indian,Chinese,Ara...     Ashok Nagar
# 3                       North Indian,Chinese,Biryani  Sholinganallur
# 4                 Continental,Mediterranean,American    Nungambakkam
#
#      CUSINE TYPE                       TIMING RATING_TYPE  RATING  VOTES  \
# 0  Casual Dining  12noon to 4pm,6pm to 1130pm   Excellent     4.6   1284
# 1  Casual Dining                  11am to 2am   Excellent     4.6   3927
# 2  Casual Dining                1130am to 1am   Excellent     4.5   3203
# 3  Casual Dining                   6am to 2am        Good     3.7   2086
# 4            Bar                3pm to 1130pm   Very Good     4.2    959
#
#                       DAYS_OPEN
# 0         Mon-Thu,12noon to ...
# 1                       Mon-Sun
# 2                       Mon-Sun
# 3                       Mon-Sun
# 4  Mon,12noon to 1130pm(Tue-Sun

# %% [markdown]
# # 5. Performing Exploratory Data Analysis
# # Q1) How many restaurants are in Mumbai for each type of cuisine?

# %%
fig = px.histogram(zomato_df, x='CUSINE TYPE', color='CUSINE TYPE',
                   title= 'No. of Restaurants by Cuisine Type',
                   labels={'CUSINE TYPE':'Cuisine Type'})

fig.show()

# %% [markdown]
# # Q2) What are the percentage of restaurants by Rating Type in Chennai?

# %%
rating_type_df = zomato_df['RATING_TYPE'].value_counts().reset_index()
rating_type_df.rename(columns={'index':'RATING TYPE', 'RATING_TYPE':'COUNT OF RESTAURANTS'}, inplace=True)
rating_type_df
# Out:
#   RATING TYPE  COUNT OF RESTAURANTS
# 0     Average                  1755
# 1        Good                  1299
# 2   Very Good                   422
# 3   Excellent                    49
# 4        Poor                    13
# 5   Very Poor                     2

# %%
fig = px.pie(rating_type_df, names='RATING TYPE', values='COUNT OF RESTAURANTS', color='RATING TYPE',
 title='Percentage of Restaurants by Rating Type').update_traces(textposition='inside', textinfo='percent+label')
fig.show()

# %% [markdown]
# # Q3) Which are the Top 10 highest rated Seafood Restaurant in Chennai?

# %%
seafood_df = zomato_df[zomato_df['CUSINE_CATEGORY'].str.contains('Seafood')]
seafood_df.sort_values(by='RATING',ascending=False).head(10)
# Out:
#                                    NAME  PRICE  \
# 1                        Copper Kitchen    800
# 2                             Palmshore   1000
# 1255                         The Marina   1600
# 1428                       Punjab Grill   1500
# 1254                      Urban Spatula    800
# 4302                            Layalee    700
# 3559  Sera - The Tapas Bar & Restaurant   1600
# 4570                       Andhra Spice    400
# 2149                             Abid's    800
# 1258                         Azzuri Bay   1000
#
#                                         CUSINE_CATEGORY         REGION  \
# 1          Seafood,North Indian,Chinese,Mughlai,Biryani          Porur
# 2     Seafood,Biryani,Kebab,North Indian,Chinese,Ara...    Ashok Nagar
# 1255                       Seafood,North Indian,Chinese   Nungambakkam
# 1428                       North Indian,Mughlai,Seafood      Velachery
# 1254  Continental,Seafood,Biryani,Italian,North Indi...     Anna Nagar
# 4302       Arabian,BBQ,Seafood,Chinese,Continental,Thai  Ekkaduthangal
# 3559                        Italian,Seafood,Finger Food    Gopalapuram
# 4570      Andhra,South Indian,Seafood,Biryani,Chettinad       T. Nagar
# 2149                 Seafood,Biryani,Hyderabadi,Arabian        Chetpet
# 1258  Italian,Mediterranean,Chettinad,Thai,South Ind...          Adyar
#
#         CUSINE TYPE                       TIMING RATING_TYPE  RATING  VOTES  \
# 1     Casual Dining                  11am to 2am   Excellent     4.6   3927
# 2     Casual Dining                1130am to 1am   Excellent     4.5   3203
# 1255  Casual Dining    12noon to 3pm,7pm to 11pm   Excellent     4.5   1002
# 1428    Fine Dining               12noon to 11pm   Very Good     4.4   1770
# 1254  Casual Dining                 11am to 11pm   Very Good     4.3    682
# 4302  Casual Dining             1130am to 1130pm   Very Good     4.3    488
# 3559            Pub            1pm to 12midnight   Very Good     4.3    930
# 4570  Casual Dining  12noon to 4pm,630pm to 11pm   Very Good     4.2     60
# 2149  Casual Dining               12noon to 11pm   Very Good     4.2    627
# 1258  Casual Dining    12noon to 3pm,7pm to 11pm   Very Good     4.2   2378
#
#                         DAYS_OPEN
# 1                         Mon-Sun
# 2                         Mon-Sun
# 1255                      Mon-Sun
# 1428                      Mon-Sun
# 1254                      Mon-Sun
# 4302                      Mon-Sun
# 3559  Mon,1230pm to 12midnight...
# 4570                      Mon-Sun
# 2149                      Mon-Sun
# 1258                      Mon-Sun

# %% [markdown]
# # Q4) Which is the best Food Truck in Chennai?

# %%
foodtruck_df = zomato_df[zomato_df['CUSINE TYPE'] == 'Food Truck']
foodtruck_df.sort_values(by='RATING',ascending=False).head(2)
# Out:
#                    NAME  PRICE        CUSINE_CATEGORY         REGION  \
# 4372  Chaska Food Truck    250  Tibetan,Chinese,Momos  Thiruvanmiyur
# 3104               Char    700           North Indian       RA Puram
#
#      CUSINE TYPE                      TIMING RATING_TYPE  RATING  VOTES  \
# 4372  Food Truck               430pm to 11pm        Good     3.9    169
# 3104  Food Truck  12noon to 3pm,6pm to 230am        Good     3.8     59
#
#      DAYS_OPEN
# 4372   Mon-Sun
# 3104   Mon-Sun

# %% [markdown]
# # Q5) Which places have the highest rated restaurant for each Cuisine Type in Chennai?

# %%
# Assuming restaurants having rating above 4.5

highest_rated_df = zomato_df[zomato_df['RATING'] >= 4.5]
highest_rated_df
# Out:
#                                               NAME  PRICE  \
# 0                            Dhaba Estd 1986 Delhi   1500
# 1                                   Copper Kitchen    800
# 2                                        Palmshore   1000
# 6                                      Axpress BBQ    700
# 7                                          Bhangra    800
# 8                                          Soy Soi   1400
# 12                       AB's - Absolute Barbecues   1400
# 21                                         Fromage   1000
# 25                                 Blind Ch3mistry    550
# 3688      7                                 Mon-Sun
# 4024    285  Mon,11am to 11pm(Tue-Sat,1230pm to ...
# 4119   1442         Mon-Thu,12noon to 12midnight...
# 4298    626                                 Mon-Sun
# 4344    143                                 Mon-Sun
# 4826   4583                                 Mon-Sun
# 4994    264                 Mon-Sat,7am to 11pm(Sun

# %%
fig = px.histogram(highest_rated_df, x='REGION', color='CUSINE TYPE',
 title= 'No. of Best Restaurant for each Cuisine Type by Places').update_xaxes(categoryorder="total descending")
fig.show()

# %% [markdown]
# # Q6) What is the Avg Price Distibution of highest rated restaurant for each Cuisine Type in Mumbai?

# %%
highest_rated_price_df = highest_rated_df.groupby(by=['REGION', 'CUSINE TYPE'])['PRICE'].mean().reset_index()
highest_rated_price_df.head()
# Out:
#           REGION     CUSINE TYPE  PRICE
# 0  Abhiramapuram          Bakery    300
# 1          Adyar   Casual Dining    700
# 2          Adyar  Dessert Parlor    150
# 3          Adyar     Fine Dining   1800
# 4       Alwarpet   Casual Dining    950

# %%
fig = px.scatter(highest_rated_price_df, x="REGION", y="PRICE", color="CUSINE TYPE", symbol="CUSINE TYPE",
 title=' Avg Price Distibution of High rated restaurant for each Cuisine Type').update_traces(marker_size=10)
fig.show()

# %% [markdown]
# # Q7) Which areas have a large number of Chinese Restaurant Market?

# %%
chinese_df = zomato_df[zomato_df['CUSINE_CATEGORY'].str.contains('Chinese')]
chinese_df
# Out:
#                        NAME  PRICE  \
# 1            Copper Kitchen    800
# 2                 Palmshore   1000
# 3            Guntur Gongura    400
# 10       Hotelkaar Biriyani    350
# 13              Arab Street    800
# ...                     ...    ...
# 5146  Shri Sakthi Fast Food    400
# 5152         Al Taj Biryani    300
# 5153              Beef Wala    300
# 5155    Shri Gowri Krishnaa    550
# 5159            Hot Kitchen    650
#
#                                         CUSINE_CATEGORY          REGION  \
# 1          Seafood,North Indian,Chinese,Mughlai,Biryani           Porur
# 2     Seafood,Biryani,Kebab,North Indian,Chinese,Ara...     Ashok Nagar
# 3                          North Indian,Chinese,Biryani  Sholinganallur
# 10                         Chinese,South Indian,Biryani        T. Nagar
# 13         Arabian,Biryani,Chinese,North Indian,Italian     Kodambakkam
# ...                                                 ...             ...
# 5146                               Chinese,North Indian     Nanganallur
# 5152                       North Indian,Biryani,Chinese      Pallavaram
# 5153                       Chinese,Biryani,North Indian     Kottivakkam
# 5155                               Chinese,North Indian       Mogappair
# 5159                               North Indian,Chinese     Injambakkam
#
#         CUSINE TYPE              TIMING RATING_TYPE  RATING  VOTES DAYS_OPEN
# 1     Casual Dining         11am to 2am   Excellent     4.6   3927   Mon-Sun
# 2     Casual Dining       1130am to 1am   Excellent     4.5   3203   Mon-Sun
# 3     Casual Dining          6am to 2am        Good     3.7   2086   Mon-Sun
# 10      Quick Bites   8am to 12midnight   Very Good     4.0    846   Mon-Sun
# 13    Casual Dining  11am to 12midnight   Very Good     4.1   1130   Mon-Sun
# ...             ...                 ...         ...     ...    ...       ...
# 5146    Quick Bites        11am to 11pm        Good     3.6     75   Mon-Sun
# 5152    Quick Bites      12noon to 11pm     Average     3.3     47   Mon-Sun
# 5153    Quick Bites     730am to 1030pm     Average     3.2     58   Mon-Sun
# 5155  Casual Dining       630am to 11pm        Good     3.8     57   Mon-Sun
# 5159  Casual Dining        11am to 11pm     Average     2.6     54   Mon-Sun
#
# [1238 rows x 10 columns]

# %%
chinese_rest_df = chinese_df.groupby(by='REGION').agg({'NAME' : 'count', 'PRICE' : 'mean'}).rename(columns= {'NAME':'COUNT OF RESTAURANTS'}).reset_index()
chinese_rest_df = chinese_rest_df.sort_values('COUNT OF RESTAURANTS', ascending=False).head(25)
chinese_rest_df.head()
# Out:
#           REGION  COUNT OF RESTAURANTS       PRICE
# 7     Anna Nagar                    74  510.135135
# 60         Porur                    41  436.585366
# 89     Velachery                    40  618.750000
# 43    Medavakkam                    38  446.052632
# 50  Nungambakkam                    36  754.166667

# %%
fig = px.bar(chinese_rest_df, x='REGION', y='COUNT OF RESTAURANTS', color='PRICE', title='No. of Chinese Restaurants by Region and Average Price')
fig.show()

# %% [markdown]
# # Q8) Is there a relation between Price and Rating by each Cuisine Type?

# %%
price_rating_df = zomato_df.groupby(['CUSINE TYPE', 'RATING'])['PRICE'].mean().reset_index()
price_rating_df
# Out:
#     CUSINE TYPE  RATING       PRICE
# 0        Bakery     2.8  400.000000
# 1        Bakery     2.9  275.000000
# 2        Bakery     3.0  333.333333
# 3        Bakery     3.1  263.636364
# 4        Bakery     3.2  315.789474
# ..          ...     ...         ...
# 226        none     4.0  456.250000
# 227        none     4.1  500.000000
# 228        none     4.2  200.000000
# 229        none     4.3  600.000000
# 230        none     4.8  100.000000
#
# [231 rows x 3 columns]

# %%
fig = px.line(price_rating_df, y="PRICE", x="RATING",color='CUSINE TYPE')

fig.show()

# %% [markdown]
# # Q9) Is there a relation between Region and Price?

# %%
region_price_df = zomato_df.groupby(['REGION'])['PRICE'].mean().reset_index()
region_price_df
# Out:
#              REGION       PRICE
# 0           T.Nagar  537.500000
# 1     Abhiramapuram  290.000000
# 2        Adambakkam  352.857143
# 3             Adyar  492.307692
# 4           Akkarai  957.142857
# ..              ...         ...
# 93  Velachery (OMR)  586.842105
# 94           Vepery  316.666667
# 95    Virugambakkam  352.500000
# 96     Washermenpet  314.000000
# 97    West Mambalam  269.354839
#
# [98 rows x 2 columns]

# %%
fig = px.scatter(region_price_df, x="REGION", y="PRICE").update_traces(marker_size=8)
fig.show()

# %% [markdown]
# # Q10) Find the list of Affordable Restaurants?
# # The criteria for Affordable Restaurants would be:-
# # 1) Low Price 2) High Rated
# # First step will be to find the restaurants with average cost 1/4th the average cost of most expensive restaurant in
# # our dataframe.
# # Let me explain:-The most expensive restaurant has an average meal cost= 6000. We'll try to stay economical and only pick the
# # restaurants that are 1/4th of 6000.

# %%
max_price = zomato_df['PRICE'].max()
one_fourth_price = max_price/4
one_fourth_price
# Out:
# 750.0

# %%
# Finding list of restaurants that have price less than and equal to 1/4th of the max price i.e Finding Cheap Restaurant

aff_rest_df = zomato_df[['NAME', 'PRICE', 'CUSINE_CATEGORY', 'REGION', 'CUSINE TYPE']]
aff_rest_df = aff_rest_df[aff_rest_df['PRICE'] <= 1250]
aff_rest_df.sort_values(by='PRICE', inplace=True)
aff_rest_df
# Out:
#                             NAME  PRICE  \
# 1842                Rekha Chaats     50
# 4717                Thanjai Mess     50
# 1729             Saravana Coffee     50
# 1847              Persian Bakery    100
# 1217  Madurai Famous Jigarthanda    100
# ...                          ...    ...
# 2510             Mascarpone Cafe   1200
# 205    Chin Chin - The Residency   1200
# 5044                    MWC Club   1200
# 3159                   SaltWater   1200
# 544                      Aristos   1250
#
#                                         CUSINE_CATEGORY        REGION  \
# 1842                                        Street Food        Vepery
# 4717                                       South Indian    K.K. Nagar
# 1729                                          Beverages   Kodambakkam
# 1847                                             Bakery     Royapuram
# 1217                                   Ice Cream,Juices     Velachery
# ...                                                 ...           ...
# 2510                      Continental,Cafe,Italian,Thai      Kanathur
# 205                                        Thai,Chinese      T. Nagar
# 5044  Chinese,Continental,Italian,South Indian,North...  Chengalpattu
# 3159                       Continental,Mexican,American   Kottivakkam
# 544   Continental,Seafood,Mediterranean,Italian,Gree...         Adyar
#
#         CUSINE TYPE
# 1842    Quick Bites
# 4717    Quick Bites
# 1729  Beverage Shop
# 1847         Bakery
# 1217    Quick Bites
# ...             ...
# 2510  Casual Dining
# 205     Fine Dining
# 5044  Casual Dining
# 3159  Casual Dining
# 544   Casual Dining
#
# [3462 rows x 5 columns]

# %%
# Finding the highest rated list of restaurants

highrate_rest_df = zomato_df[['NAME', 'PRICE', 'CUSINE_CATEGORY', 'REGION', 'CUSINE TYPE','RATING']]
highrate_rest_df = highrate_rest_df[highrate_rest_df['RATING'] >= 4.5]
highrate_rest_df.sort_values(by='PRICE', inplace=True)
highrate_rest_df
# Out:
#                                               NAME  PRICE  \
# 900                                   Bombay Lassi    100
# 2675                                  Bombay Kulfi    150
# 1259                                Eating Circles    250
# 1802                         Prems Graama Bhojanam    300
# 2152                          Fresh Baked Goodness    300
# 2674                             The Sandwich Shop    300
# 731               Momo Sa-Khang by Kailash Kitchen    300
# 4344                       Fresh Cakes by Bakerzoh    300
# 4298                                        Shakos    300
# 3688                               Dhakshina kanni    350
# 2146                                Brownie Heaven    400
# 4024            Shmoozie's Hand-Crafted Ice creams    400
# 1794                                     Waf O'Bel    400
# 725                                Fusilli Reasons    400
# 26                               Milkshake And Co.    400
# 1611                                  Kabab Corner    450
# 1424                                     BurgerMan    500
# 4119            Amadora Gourmet Ice Cream & Sorbet    500
# 25                                 Blind Ch3mistry    550
# 4826                                        Onesta    600
# 6                                      Axpress BBQ    700
# 730                                          Mezze    700
# 1                                   Copper Kitchen    800
# 7                                          Bhangra    800
# 1434                                 Pumpkin Tales    950
# 21                                         Fromage   1000
# 906                         Va Pho - Asian Canteen   1000
# 546      VB Signature - Progressive Veg Restaurant   1000
# 2                                        Palmshore   1000
# 370                            Cleo's Grill & Cafe   1100
# 377                      Grill Box - Unlimited BBQ   1200
# 1076                           Sigree Global Grill   1200
# 3563                                      Wok Monk   1200
# 372                                   Nasi And Mee   1200
# 4994                            Broken Bridge Cafe   1350
# 12                       AB's - Absolute Barbecues   1400
# 380                   Chili's American Grill & Bar   1400
# 8                                          Soy Soi   1400
# 0                            Dhaba Estd 1986 Delhi   1500
# 1609                                  Little Italy   1500
# 1079                Asia Kitchen by Mainland China   1500
# 547                                       Mamagoto   1500
# 1802   Casual Dining     4.7
# 2152          Bakery     4.5
# 2674     Quick Bites     4.6
# 731      Quick Bites     4.7
# 4344          Bakery     4.6
# 4298  Dessert Parlor     4.5
# 3688     Quick Bites     4.5
# 2146  Dessert Parlor     4.6
# 4024  Dessert Parlor     4.7
# 1794  Dessert Parlor     4.6
# 725      Quick Bites     4.6
# 26     Beverage Shop     4.8
# 1611     Quick Bites     4.5
# 1424   Casual Dining     4.5
# 4119  Dessert Parlor     4.6
# 25              Café     4.5
# 4826   Casual Dining     4.7
# 6      Casual Dining     4.7
# 730    Casual Dining     4.6
# 1      Casual Dining     4.6
# 7      Casual Dining     4.9
# 1434   Casual Dining     4.5
# 21              Café     4.5
# 906    Casual Dining     4.5
# 546    Casual Dining     4.5
# 2      Casual Dining     4.5
# 370    Casual Dining     4.5
# 377    Casual Dining     4.6
# 1076   Casual Dining     4.6
# 3563   Casual Dining     4.7
# 372    Casual Dining     4.7
# 4994            Café     4.5
# 12     Casual Dining     4.8
# 380    Casual Dining     4.7
# 8      Casual Dining     4.5
# 0      Casual Dining     4.6
# 1609   Casual Dining     4.5
# 1079   Casual Dining     4.6
# 547    Casual Dining     4.5
# 368    Casual Dining     4.5
# 1787   Casual Dining     4.5
# 908    Casual Dining     4.7
# 1255   Casual Dining     4.5
# 1083     Fine Dining     4.5
# 206    Casual Dining     4.6
# 728      Fine Dining     4.6
# 1778     Fine Dining     4.6

# %% [markdown]
# # Now, we'll merge the aff_rest_df with highrate_rest_df to obtain the intersection i.e the list of Affordable Restaurants !!

# %%
highrate_aff_df = pd.merge(aff_rest_df, highrate_rest_df, how='inner', on=['NAME', 'REGION'])
highrate_aff_df = highrate_aff_df[['NAME', 'PRICE_x', 'CUSINE_CATEGORY_x', 'REGION', 'CUSINE TYPE_x']]
highrate_aff_df.rename(columns={'NAME':'NAME', 'PRICE_x':'PRICE', 'CUSINE_CATEGORY_x':'CUSINE_CATEGORY',
 'REGION':'REGION', 'CUSINE TYPE_x':'CUSINE TYPE'},inplace=True)

# %%
# Affordable Restaurants with low price and high rating

highrate_aff_df
# Out:
#                                          NAME  PRICE  \
# 0                                Bombay Lassi    100
# 1                                Bombay Kulfi    150
# 2                              Eating Circles    250
# 3                       Prems Graama Bhojanam    300
# 4                     Fresh Cakes by Bakerzoh    300
# 5                                      Shakos    300
# 6                        Fresh Baked Goodness    300
# 7                           The Sandwich Shop    300
# 8            Momo Sa-Khang by Kailash Kitchen    300
# 9                             Dhakshina kanni    350
# 10         Shmoozie's Hand-Crafted Ice creams    400
# 11                            Fusilli Reasons    400
# 12                             Brownie Heaven    400
# 13                                  Waf O'Bel    400
# 14                          Milkshake And Co.    400
# 15                               Kabab Corner    450
# 16                                  BurgerMan    500
# 17         Amadora Gourmet Ice Cream & Sorbet    500
# 18                            Blind Ch3mistry    550
# 19                                     Onesta    600
# 20                                      Mezze    700
# 21                                Axpress BBQ    700
# 22                                    Bhangra    800
# 23                             Copper Kitchen    800
# 24                              Pumpkin Tales    950
# 25                                  Palmshore   1000
# 26                                    Fromage   1000
# 27  VB Signature - Progressive Veg Restaurant   1000
# 28                     Va Pho - Asian Canteen   1000
# 29                        Cleo's Grill & Cafe   1100
# 30                  Grill Box - Unlimited BBQ   1200
# 31                        Sigree Global Grill   1200
# 32                                   Wok Monk   1200
# 33                               Nasi And Mee   1200
#
#                                       CUSINE_CATEGORY          REGION  \
# 0                                         Street Food      Triplicane
# 1                                           Ice Cream           Adyar
# 2                                        South Indian        Alwarpet
# 3                                        South Indian           Adyar
# 4                                     Bakery,Desserts         Kilpauk
# 5                        Desserts,Beverages,Fast Food      Anna Nagar
# 6                                     Bakery,Desserts   Abhiramapuram
# 7                                  Fast Food,Sandwich   West Mambalam
# 8                                       Tibetan,Momos     Choolaimedu
# 9                                North Indian,Chinese  Sholinganallur
# 10                                 Ice Cream,Desserts          Egmore
# 11                                            Italian         Kilpauk
# 12                                           Desserts         T.Nagar
# 13                                 Desserts,Beverages         Chetpet
# 14                                Beverages,Fast Food    Besant Nagar
# 15                                        Kebab,Rolls          Egmore
# 16  Continental,Burger,American,Beverages,Fast Foo...    Besant Nagar
# 17                                 Desserts,Ice Cream    Nungambakkam
# 18                           Cafe,Fast Food,Beverages    Besant Nagar
# 19         Pizza,Italian,Fast Food,Beverages,Desserts     Semmancheri
# 20                                     Middle Eastern        RA Puram
# 21             Kebab,BBQ,North Indian,Rolls,Malaysian      Karapakkam
# 22                                       North Indian        Kanathur
# 23       Seafood,North Indian,Chinese,Mughlai,Biryani           Porur
# 24   Singaporean,American,Bakery,Continental,European        Alwarpet
# 25  Seafood,Biryani,Kebab,North Indian,Chinese,Ara...     Ashok Nagar
# 26                       Cafe,Italian,French,European   Mahabalipuram
# 27            North Indian,South Indian,Chinese,Asian    Nungambakkam
# 28                                        Asian,Momos     Gopalapuram
# 29             Chinese,Continental,Steak,North Indian           Adyar
# 30                      North Indian,South Indian,BBQ        Mylapore
# 31                 North Indian,Mexican,Mediterranean    Nungambakkam
# 32  Thai,Chinese,Japanese,Indonesian,Malaysian,Bur...      Anna Nagar
# 33     Singaporean,Malaysian,Chinese,Asian,Thai,Momos    Nungambakkam
#
#        CUSINE TYPE
# 0             none
# 1   Dessert Parlor
# 2      Quick Bites
# 3    Casual Dining
# 4           Bakery
# 5   Dessert Parlor
# 6           Bakery
# 7      Quick Bites
# 8      Quick Bites
# 9      Quick Bites
# 10  Dessert Parlor
# 11     Quick Bites
# 12  Dessert Parlor
# 13  Dessert Parlor
# 14   Beverage Shop
# 15     Quick Bites
# 16   Casual Dining
# 17  Dessert Parlor
# 18            Café
# 19   Casual Dining
# 20   Casual Dining
# 21   Casual Dining
# 22   Casual Dining
# 23   Casual Dining
# 24   Casual Dining
# 25   Casual Dining
# 26            Café
# 27   Casual Dining
# 28   Casual Dining
# 29   Casual Dining
# 30   Casual Dining
# 31   Casual Dining
# 32   Casual Dining
# 33   Casual Dining

# %% [markdown]
# # Q10) Find the list of most Reliable Restaurants?
# # The criteria for most Reliable Restaurants would be:-
# # 1) Low Price 2) High Rated 3) Large No. of Votes
# # First step will be to find the restaurants with Votes greater than Mean of Votes

# %%
mean_votes = zomato_df['VOTES'].mean()
mean_votes
# Out:
# 149.42090395480227

# %%
# Finding list of restaurants that have Votes greater than and equal to Mean of Vote
mean_rest_df = zomato_df[['NAME', 'PRICE', 'CUSINE_CATEGORY', 'REGION', 'CUSINE TYPE', 'VOTES']]
mean_rest_df = mean_rest_df[mean_rest_df['VOTES'] > 177]
mean_rest_df.sort_values(by='VOTES', inplace=True)
mean_rest_df
# Out:
#                           NAME  PRICE  \
# 4381                   Lydie's   1550
# 4400            Arcot Biriyani    300
# 4037                    Pulusu    500
# 4457  Velu Military Restaurant    700
# 4093                 First Cup    400
# ...                        ...    ...
# 2                    Palmshore   1000
# 1               Copper Kitchen    800
# 382                     Maplai   1000
# 4826                    Onesta    600
# 18                    Paradise    800
#
#                                         CUSINE_CATEGORY         REGION  \
# 4381                           Continental,South Indian  Mahabalipuram
# 4400                                    Biryani,Chinese          Porur
# 4037  Andhra,Biryani,South Indian,Desserts,Beverages...       Ambattur
# 4457                                  Chettinad,Chinese    Ashok Nagar
# 4093                                               Cafe   Nungambakkam
# ...                                                 ...            ...
# 2     Seafood,Biryani,Kebab,North Indian,Chinese,Ara...    Ashok Nagar
# 1          Seafood,North Indian,Chinese,Mughlai,Biryani          Porur
# 382                      Chettinad,Biryani,South Indian   Nungambakkam
# 4826         Pizza,Italian,Fast Food,Beverages,Desserts    Semmancheri
# 18                         Biryani,North Indian,Chinese      Perungudi
#
#         CUSINE TYPE  VOTES
# 4381  Casual Dining    178
# 4400    Quick Bites    178
# 4037  Casual Dining    178
# 4457  Casual Dining    178
# 4093           Café    179
# ...             ...    ...
# 2     Casual Dining   3203
# 1     Casual Dining   3927
# 382   Casual Dining   4228
# 4826  Casual Dining   4583
# 18    Casual Dining   4643
#
# [748 rows x 6 columns]

# %% [markdown]
# # These are the most reliable, highest rated and affordable restaurants:-
# # We obtain this dataframe by simply taking the intersection of highrate_aff_df & mean_rest_df
# # This dataframe obtained below shows the restaurants whose:
# # Cost is below 1250
# # Rating is above 4.5
# # Votes are above 177

# %%
reliable_rest_df = pd.merge(mean_rest_df, highrate_aff_df, how='inner', on=['NAME', 'REGION'])
reliable_rest_df = reliable_rest_df[['NAME', 'PRICE_x', 'CUSINE_CATEGORY_x', 'REGION', 'CUSINE TYPE_x']]
reliable_rest_df.rename(columns={'NAME':'NAME', 'PRICE_x':'PRICE', 'CUSINE_CATEGORY_x':'CUSINE_CATEGORY',
 'REGION':'REGION', 'CUSINE TYPE_x':'CUSINE TYPE'},inplace=True)

# %%
reliable_rest_df
# Out:
#                                          NAME  PRICE  \
# 0          Shmoozie's Hand-Crafted Ice creams    400
# 1                                    Wok Monk   1200
# 2                              Eating Circles    250
# 3                                Bombay Kulfi    150
# 4                        Fresh Baked Goodness    300
# 5                                 Axpress BBQ    700
# 6                           The Sandwich Shop    300
# 7                               Pumpkin Tales    950
# 8                                      Shakos    300
# 9                         Sigree Global Grill   1200
# 10                             Brownie Heaven    400
# 11                               Bombay Lassi    100
# 12                                    Fromage   1000
